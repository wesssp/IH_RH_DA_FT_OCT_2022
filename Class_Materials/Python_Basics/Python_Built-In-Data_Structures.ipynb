# %% [markdown]
# # Python Built-In Data Structures

# %% [markdown]
# ## Lists

# %%
TAs = ["Aleks"]

# %%
type(TAs)
# Out:
# list

# %%
TAs
# Out:
# ['Aleks']

# %% [markdown]
# #### Indexing, slicing, appending

# %%
TAs[0]
# Out:
# 'Aleks'

# %%
LT = "Rafa"

# %%
teachers = [LT] + TAs

# %%
teachers
# Out:
# ['Rafa', 'Aleks']

# %%
print(teachers)
# Out:
# ['Rafa', 'Aleks']

# %%
len(teachers)
# Out:
# 2

# %% [markdown]
# #### Iterating through lists

# %%
for teacher in teachers:
    print(teacher + " is a teacher!")
# Out:
# Rafa is a teacher!
# Aleks is a teacher!

# %%
students=['Aykut AvciAvci',  'Elisabeth Oeljeklaus', 'Esra Becker', 'Felipe Burattini',
          'Gunnar David', 'Iryna Nesterenko', 'Marlena Kowieska', 'Pablo Herranz', 
          'Paul Kollhof', 'Paul-Moritz Jost', 'Rodrigo Franco', 'Rotem Sioni']

# %%
students
# Out:
# ['Aykut AvciAvci',
#  'Elisabeth Oeljeklaus',
#  'Esra Becker',
#  'Felipe Burattini',
#  'Gunnar David',
#  'Iryna Nesterenko',
#  'Marlena Kowieska',
#  'Pablo Herranz',
#  'Paul Kollhof',
#  'Paul-Moritz Jost',
#  'Rodrigo Franco',
#  'Rotem Sioni']

# %% [markdown]
# #### Print students with names starting with j

# %%
for student in students:
    if ( student[-1]=='a'):
        print(student)
# Out:
# Marlena Kowieska

# %% [markdown]
# #### Create two lists: "student_names" and "student_surnames"

# %%
student_names = []
student_surnames = []

# %%
for student in students:
    student_split = student.split()
    ## populating the first names 
    student_names.append(student_split[0])
    ## populating the seond list which contains the last names 
    student_surnames.append(student_split[1])

# %%
student_names
# Out:
# ['Aykut',
#  'Elisabeth',
#  'Esra',
#  'Felipe',
#  'Gunnar',
#  'Iryna',
#  'Marlena',
#  'Pablo',
#  'Paul',
#  'Paul-Moritz',
#  'Rodrigo',
#  'Rotem']

# %% [markdown]
# #### Print the surname for "".

# %%
index_student = student_names.index("Elisabeth")

# %%
student_surnames[index_student]
# Out:
# 'Oeljeklaus'

# %%
print(student_names)
input("Select one of the following names: ")
# Out:
# ['Aykut', 'Elisabeth', 'Esra', 'Felipe', 'Gunnar', 'Iryna', 'Marlena', 'Pablo', 'Paul', 'Paul-Moritz', 'Rodrigo', 'Rotem']
# Select one of the following names: Esra
# 'Esra'

# %% [markdown]
# ## Dictionaries

# %%
ages = {"Raafat": 19,
        "Aleks":18
       }

# %%
ages
# Out:
# {'Raafat': 19, 'Aleks': 18}

# %% [markdown]
# #### Accessing keys & values

# %%
list(ages.keys())
# Out:
# ['Raafat', 'Aleks']

# %%
list(ages.keys())[0]
# Out:
# 'Raafat'

# %%
list(ages.values())
# Out:
# [19, 18]

# %%
ages["Raafat"]
# Out:
# 19

# %%
len(ages)
# Out:
# 2

# %% [markdown]
# #### Iterate through dictionary

# %%
for teacher in ages.keys():
    print(teacher + " is " + str(ages[teacher]) + " years old.")
# Out:
# Raafat is 19 years old.
# Aleks is 18 years old.

# %% [markdown]
# <b> iterating using items() function

# %%
for teacher,age in ages.items():
    print (teacher + " is "+ str(age) +" years old ")
# Out:
# Raafat is 19 years old
# Aleks is 18 years old

# %% [markdown]
# #### Nested dictionaries
#
# Create a dictionary of teachers. For it teacher, it stores their age, role and the city where they live.

# %%
teachers_dict = {
    "Raafat":{
        "age": 19,
        "role":"LT",
        "city_residence":"Berlin"
    },
    "Aleks":{
        "age":18,
        "role":"TA",
        "city_residence":"London"
    }
}

# %% [markdown]
# #### Print only name of teachers who live in Berlin

# %%
for teacher in teachers_dict.keys():
    teacher_Info=teachers_dict[teacher]
    if teacher_Info["city_residence"] == "Berlin":
        print(teacher + " lives in Berlin")
# Out:
# Raafat lives in Berlin

# %% [markdown]
# ## Tuples

# %%
teachers
# Out:
# ['Rafa', 'Aleks']

# %%
teachers_tuple = tuple(teachers)

# %%
teachers_tuple
# Out:
# ('Rafa', 'Aleks')

# %%
teachers_tuple[1] = "Jan"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 teachers_tuple[1] = "Jan"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Set

# %%
import random

# %%
random.randint(1, 100)
# Out:
# 77

# %% [markdown]
# #### Take a random sample (with replacement) of 100 numbers from 1 to 100:

# %%
random_numbers = []

for i in range(100):
    random_numbers.append(random.randint(1, 100))

# %%
random_numbers
# Out:
# [6,
#  48,
#  22,
#  74,
#  69,
#  39,
#  65,
#  56,
#  85,
#  47,
#  16,
#  87,
#  71,
#  8,
#  66,
#  55,
#  7,
#  1,
#  97,
#  5,
#  95,
#  36,
#  23,
#  87,
#  39,
#  7,
#  97,
#  19,
#  12,
#  33,
#  34,
#  74,
#  76,
#  98,
#  84,
#  94,
#  53,
#  9,
#  40,
#  21,
#  17,
#  97,
#  66,
#  1,
#  39,
#  88,
#  42,
#  67,
#  66,
#  43,
#  85,
#  20,
#  50,
#  8,
#  81,
#  54,
#  44,
#  16,
#  8,
#  3,
#  19,
#  24,
#  47,
#  16,
#  94,
#  81,
#  75,
#  83,
#  39,
#  82,
#  75,
#  98,
#  91,
#  13,
#  47,
#  24,
#  63,
#  46,
#  33,
#  61,
#  3,
#  12,
#  71,
#  13,
#  52,
#  68,
#  48,
#  65,
#  69,
#  64,
#  62,
#  91,
#  45,
#  88,
#  65,
#  47,
#  83,
#  19,
#  38,
#  67]

# %%
len(set(random_numbers))
# Out:
# 61

# %% [markdown]
# ### set union

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}

z = x.union(y)
z
# Out:
# {'apple', 'banana', 'cherry', 'google', 'microsoft'}
